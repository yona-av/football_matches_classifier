# %%
# import modules 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import os 
import sys
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# import , prepare the data for EDA part

data_barca=pd.read_csv(r"C:/Users/Yehonatan/Documents/DS/proj barca data edited.csv")
data_barca['save_per']=data_barca['save_per'].fillna(100) # no shots on target means no saves in a way same effect as 100% saves
data_barca= data_barca.dropna(subset=['lps_cmp_per']) # drop the row of nan cell for practice 

data_barca = data_barca.replace({'venue': { 'Home' : 1, 'Away' : 0, }}) # replace categorical data to numerical
data_barca = data_barca.replace({'result': { 'W' : 1, 'D' : 0, 'L' : -1 }})

#convert the data frame into float64 dtype 
columns_names=list(data_barca_try)
data_barca_np=data_barca.to_numpy()
data_barca = pd.DataFrame(data_barca_np, columns = columns_names)
#data_barca.info()

# %%
# EDA 
data_barca.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# divide to x,y sets 
y = data_barca['result']
x = data_barca.drop(['result'], axis=1)

# divide into test set and train set   
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=9)
